# %%
# !pip install librosa
# !pip install midiutil

# %%
import librosa
import numpy as np
import pandas as pd
import math
audio, sr = librosa.load("Misirlou.wav", sr = 16000)

# %%
spectrogram = librosa.stft(audio, n_fft=2048, hop_length=256, center=False, win_length=2048) 
M = abs(spectrogram)
phase = spectrogram/(M + 2.2204e-16)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True)
D = librosa.amplitude_to_db(np.abs(librosa.stft(audio)), ref=np.max)
img = librosa.display.specshow(D, y_axis='linear', x_axis='time',sr=sr, ax=ax[0])
ax[0].set(title='Linear-frequency power spectrogram')
ax[0].label_outer()

# %%
file_paths = [
    'notes_scale/0.wav',
    'notes_scale/1.wav',
    'notes_scale/2.wav',
    'notes_scale/3.wav',
    'notes_scale/4.wav',
    'notes_scale/5.wav',
    'notes_scale/6.wav'
]
def process_wav_librosa(file_path):
    # Load the audio file
    data, rate = librosa.load(file_path, sr=16000)
    
    # Compute the Short-Time Fourier Transform (STFT)
    S = abs(librosa.stft(data,n_fft=2048, hop_length=256, center=False, win_length=2048))
    
    # Extract the middle column (STFT is frequency x time, we want the middle time column)
    middle = S[:, int(math.ceil(S.shape[1]/2))]
    middle[middle < (max(middle)/100)] = 0
    middle = middle/np.linalg.norm(middle)
    
    return middle

# Process all WAV files using librosa and store the resulting vectors
spectrogram_vectors_librosa = [process_wav_librosa(file_path) for file_path in file_paths]

# %%
Notes=np.array(spectrogram_vectors_librosa)
Notes=Notes.T

# %%
X= np.dot(Notes.T,Notes)

# %%
Y=np.dot(np.linalg.inv(X),Notes.T)

# %%
W=np.dot(Y,M)

# %%
W
# Out:
# array([[ 0.07458599,  0.27390325,  0.6394622 , ...,  1.9085155 ,
#          1.3860337 ,  1.0385977 ],
#        [ 0.09169007,  0.18716805,  1.3439909 , ...,  2.8430336 ,
#          2.1693478 ,  1.6114863 ],
#        [ 0.00481587,  0.27018124,  1.5982854 , ...,  0.73262614,
#          0.6986367 ,  0.6117892 ],
#        ...,
#        [ 0.01106299,  0.1267945 ,  1.4237995 , ...,  0.344202  ,
#          0.46096197,  0.45694295],
#        [ 0.06537553,  0.24150383,  1.3333008 , ..., -0.6129355 ,
#         -0.639801  , -0.51283616],
#        [ 0.07403076,  0.20200017,  0.6971352 , ..., -0.24066563,
#         -0.22292149, -0.14626208]], dtype=float32)

# %%
newDataset = M-np.dot(Notes,W)
finalDataset = np.linalg.norm(newDataset, 'fro')**2
print(finalDataset)
# Out:
# 4080522.305603981

# %%
df = pd.DataFrame(W.T, columns=['Note1', 'Note2', 'Note3','Note4','Note5','Note6','Note7'])  # Add column names if needed

# Save the DataFrame to a CSV file
df.to_csv('problem1.csv', index=False)  # index=False to avoid saving row numbers

print("Array saved to 'output.csv'")
# Out:
# Array saved to 'output.csv'

# %%
import soundfile as sf
import IPython.display as ipd
W[W < 0] = 0 # remove all negative values

M_hat = Notes @ W # reconstructing audio data matrix from Notes and frequency weights at times
M_hat_spectogram = M_hat * np.exp(1j*phase) # creating spectogram for M_hat for inverse stft

Y_hat = librosa.istft(M_hat_spectogram, hop_length=256, win_length=2048, center=False) # inverse stftY)
print(Y_hat)

sf.write('resynthensized proj.wav', Y_hat, 16000)
ipd.Audio('resynthensized proj.wav', rate=16000)
